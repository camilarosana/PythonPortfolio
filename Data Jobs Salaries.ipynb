# %% [markdown]
# # Data Jobs Salaries

# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\user 1\Downloads\archive.zip")
df
# Out:
#       work_year experience_level employment_type                  job_title  \
# 0          2023               SE              FT             Data Scientist
# 1          2023               SE              FT             Data Scientist
# 2          2023               SE              FT  Machine Learning Engineer
# 3          2023               SE              FT  Machine Learning Engineer
# 4          2023               SE              FT                ML Engineer
# ...         ...              ...             ...                        ...
# 8108       2020               SE              FT             Data Scientist
# 8109       2021               MI              FT   Principal Data Scientist
# 8110       2020               EN              FT             Data Scientist
# 8111       2020               EN              CT      Business Data Analyst
# 8112       2021               SE              FT       Data Science Manager
#
# ...

# %%
#Ver as 10 primeiras linhas
df.head(10)
# Out:
#    work_year experience_level employment_type                  job_title  \
# 0       2023               SE              FT             Data Scientist
# 1       2023               SE              FT             Data Scientist
# 2       2023               SE              FT  Machine Learning Engineer
# 3       2023               SE              FT  Machine Learning Engineer
# 4       2023               SE              FT                ML Engineer
# 5       2023               SE              FT                ML Engineer
# 6       2023               SE              FT              Data Engineer
# 7       2023               SE              FT              Data Engineer
# 8       2023               SE              FT               Data Analyst
# 9       2023               SE              FT               Data Analyst
#
#    salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0  199000             USD         199000                 US             0
# ...

# %%
#Ver as 10 últimas linhas 
df.tail(10)
# Out:
#       work_year experience_level employment_type  \
# 8103       2021               SE              FT
# 8104       2021               MI              FT
# 8105       2021               MI              FT
# 8106       2021               MI              FT
# 8107       2021               SE              FT
# 8108       2020               SE              FT
# 8109       2021               MI              FT
# 8110       2020               EN              FT
# 8111       2020               EN              CT
# 8112       2021               SE              FT
#
#                                job_title   salary salary_currency  \
# 8103            Director of Data Science   168000             USD
# 8104                      Data Scientist   160000             SGD
# 8105  Applied Machine Learning Scientist   423000             USD
# 8106                       Data Engineer    24000             EUR
# 8107                     Data Specialist   165000             USD
# ...

# %%
#Deletando colunas
df = df.drop(columns = ["employment_type", "remote_ratio", "salary_currency", "salary_in_usd"])
df
# Out:
#       work_year experience_level                  job_title   salary  \
# 0          2023               SE             Data Scientist   199000
# 1          2023               SE             Data Scientist   196760
# 2          2023               SE  Machine Learning Engineer    90000
# 3          2023               SE  Machine Learning Engineer    70000
# 4          2023               SE                ML Engineer   324000
# ...         ...              ...                        ...      ...
# 8108       2020               SE             Data Scientist   412000
# 8109       2021               MI   Principal Data Scientist   151000
# 8110       2020               EN             Data Scientist   105000
# 8111       2020               EN      Business Data Analyst   100000
# 8112       2021               SE       Data Science Manager  7000000
#
#      employee_residence company_location company_size
# 0                    US               US            M
# ...

# %%
df.describe()
# Out:
#          work_year        salary
# count  8113.000000  8.113000e+03
# mean   2022.715149  1.767508e+05
# std       0.559426  4.746788e+05
# min    2020.000000  1.400000e+04
# 25%    2023.000000  1.060000e+05
# 50%    2023.000000  1.450000e+05
# 75%    2023.000000  1.900000e+05
# max    2023.000000  3.040000e+07

# %%
#Valores exclusivos 
df.nunique()
# Out:
# work_year                4
# experience_level         4
# job_title              119
# salary                1360
# employee_residence      85
# company_location        73
# company_size             3
# dtype: int64

# %%
#Filtrando os maiores salários
df.sort_values(by="salary", ascending=False).head()
# Out:
#       work_year experience_level                       job_title    salary  \
# 8034       2021               MI                  Data Scientist  30400000
# 8013       2020               MI                  Data Scientist  11000000
# 7943       2021               MI                 BI Data Analyst  11000000
# 7850       2021               MI                     ML Engineer   8500000
# 7347       2022               SE  Lead Machine Learning Engineer   7500000
#
#      employee_residence company_location company_size
# 8034                 CL               CL            L
# 8013                 HU               HU            L
# 7943                 HU               US            L
# 7850                 JP               JP            S
# 7347                 IN               IN            L

# %%
#Filtrando os menores salários
df.sort_values(by="salary").head()
# Out:
#       work_year experience_level                        job_title  salary  \
# 7945       2020               EN                      ML Engineer   14000
# 7218       2021               EN       Machine Learning Developer   15000
# 4590       2020               EX               Staff Data Analyst   15000
# 2379       2022               MI  Business Intelligence Developer   15000
# 7515       2022               EN                     Data Analyst   15000
#
#      employee_residence company_location company_size
# 7945                 DE               DE            S
# 7218                 TH               TH            L
# 4590                 NG               CA            M
# 2379                 GH               GH            M
# 7515                 ID               ID            L
